# %% [markdown]
# ## Optimize Prompts with an OPRO implementation
# ### Apply it to a text classification task
#
# OPRO:
# - https://arxiv.org/pdf/2309.03409
# - https://github.com/google-deepmind/opro

# %%
import boto3
import re
import time
import pandas as pd
from multiprocessing.pool import ThreadPool
from threading import Lock

# %%
DATASET_CSV = 'train.csv'
NUM_EXAMPLES = 3
NUM_ITERATIONS = 6
NUM_SAMPLES = 20

# %%
# Define allowed categories and seed prompts
ALLOWED_CATEGORIES = ['ADVOCATE', 'BUSINESS-DEVELOPMENT', 'CONSULTANT', 'FITNESS',
       'HEALTHCARE', 'PUBLIC-RELATIONS', 'CHEF', 'SALES', 'FINANCE',
       'ARTS', 'ENGINEERING', 'HR', 'INFORMATION-TECHNOLOGY', 'DESIGNER',
       'CONSTRUCTION', 'ACCOUNTANT', 'AVIATION', 'AGRICULTURE',
       'DIGITAL-MEDIA', 'TEACHER', 'BANKING', 'APPAREL', 'AUTOMOBILE',
       'BPO']

OUTPUT_FORMAT_INSTRUCTIONS = """The output should be formatted as a JSON document that conforms to the following JSON schema:
{"properties": {"reasoning": {"title": "Reasoning", "type": "string"}, "predicted_category": {"title": "Predicted Category", "type": "string"}}, "required": ["predicted_category"], "example": {"reasoning": "The canidadate had worked as a graphic designer at several media companies.", "predicted_category": "DESIGNER"}}
"""

SEED_PROMPTS = [
"""You are an HR recruiter. Review candidate's resume and classify the candidate to one of the following categories: {categories}.
""",
"""You are an assistant in the HR department. Classify the following resume into one of the following categories: {categories}.
""",
"""Review the following resume and assign it to one of the following categories: {categories}.
"""
]

# %%
# Initialize Bedrock client
bedrock = boto3.client('bedrock-runtime')

# %%
SONNET = 'anthropic.claude-3-sonnet-20240229-v1:0'
HAIKU = 'anthropic.claude-3-haiku-20240307-v1:0'
stats = {
    SONNET: {'in': 0, 'out': 0},
    HAIKU: {'in': 0, 'out': 0}
}
lock = Lock()

# %%
def trim_uppercase_words(text):
    # Remove leading whitespace
    text = text.lstrip()
    # Find the index of the first lowercase word (if any)
    pattern = r'^[A-Z/\-\s]+(\w*)'
    match = re.search(pattern, text)
    if match:
        start_index = match.end(1)
        return text[start_index:].lstrip()
    else:
        return text

# %%
def load_dataset():
    splits = {'train': 'train.csv', 'test': 'test.csv'}
    df = pd.read_csv("hf://datasets/Manirathinam21/Resume_classification/" + splits["train"])
    df = df.groupby('label').sample(n=5, replace=False).sample(frac=1).reset_index(drop=True)
    df['text'] = df['text'].apply(trim_uppercase_words)
    df.to_csv(DATASET_CSV, index=False)
    df.head
    return df

# %%
def converse(prompt, model, temperature, maxTokens):
    for i in range(3):  # retries
        try:
            response = bedrock.converse(modelId=model,
                        messages=[
                           {"role": "user", "content": [{"text": prompt}]}
                        ],
                        inferenceConfig={
                            "temperature": temperature,
                            "maxTokens": maxTokens
                        })
            with lock:
                stats[model]['in'] += response['usage']['inputTokens']
                stats[model]['out'] += response['usage']['outputTokens']
            return response['output']['message']['content'][0]['text']
        except Exception as e:
            print(e)
            time.sleep(60)
            continue
    return "Model invocation error"

def call_optimizer(prompt):
    return converse(prompt, SONNET, 1.0, 4000)

def call_model(prompt):
    return converse(prompt, HAIKU, 1.0, 1000)

def call_scorer(prompt):
    return converse(prompt, HAIKU, 0.0, 10)

# %%
def extract_prediction(text):
    prompt_template = """Search for the categorization result in a given text. Categories: {categories}.
    Text: {text}. Look for an exact match. Write only the extracted category. Category:"""
    prompt = prompt_template.format(categories=", ".join(ALLOWED_CATEGORIES), text=text)
    keyword = call_scorer(prompt)
    return keyword

# %%
def evaluate_prompt(prompt, samples):
    """Evaluate a prompt on a subset of the dataset."""
    correct = 0
    for i, sample in samples.iterrows():
        prompt = prompt.replace('{categories}', ", ".join(ALLOWED_CATEGORIES))
        full_prompt = f"{prompt}\n\text: {sample['text']}\n{OUTPUT_FORMAT_INSTRUCTIONS}"
        prediction = call_model(full_prompt).strip()
        if extract_prediction(prediction) == sample['label']:
            print("1", end="")
            correct += 1
        else:
            print("0", end="")
    return correct / len(samples)

# %%
def evaluate_prompts(instructions, dataset):
    try:
        n = len(instructions)
        pool = ThreadPool(n)
        samples = [dataset.sample(n=min(NUM_SAMPLES, dataset.shape[0])) for i in range(n)]
        async_result = pool.starmap_async(evaluate_prompt, zip(instructions, samples))
        results = async_result.get()
        pool.close()
        print(results)
        return results
    except Exception as e:
        print(e)
        return []

# %%
def extract_inst(text):
    pattern = r'<inst>(.*?)</inst>'
    matches = re.findall(pattern, text, re.DOTALL)
    return matches

def generate_instructions(meta_prompt):
    """Generate new instructions using optimizer LLM."""
    response = call_optimizer(meta_prompt)
    instructions = extract_inst(response)
    print("Generated prompts:", instructions)
    return instructions[:3]  # Limit to 3 instructions

def format_instructions(instructions, scores):
    """Format instructions with their scores for the meta-prompt."""
    return "\n".join([f"Instruction: {instr}\nScore: {score:.4f}" for instr, score in zip(instructions, scores)])

def generate_examples(dataset, num_examples):
    """Generate example texts with their categories."""
    examples = dataset.sample(n=num_examples)
    return "\n\n".join([f"Text: {ex['text']}\nCategory: {ex['label']}" for i,ex in examples.iterrows()])

# %%
def optimize(dataset, num_iterations=NUM_ITERATIONS):
    """Implement the OPRO algorithm for prompt optimization."""
    print("Optimizing...")
    best_instructions = SEED_PROMPTS
    best_scores = evaluate_prompts(best_instructions, dataset)
    
    for iteration in range(num_iterations):
        print(f"Iteration {iteration + 1}")
        
        # Prepare meta-prompt
        meta_prompt = f"""
        You are an AI assistant tasked with generating instructions for a text classification task.
        The goal is to classify text into one of these categories: {", ".join(ALLOWED_CATEGORIES)}.
        
        Here are some example texts with their correct categories:
        <examples>
        {generate_examples(dataset, NUM_EXAMPLES)}
        </examples>
        
        Previous instructions and their scores (higher is better):
        <previous_instructions>
        {format_instructions(best_instructions, best_scores)}
        </previous_instructions>
        
        Please generate 3 new instruction sets that could potentially achieve higher accuracy.
        Each instruction-set should be enclosed inside <inst></inst> tags.
        Leverage previous instructions and examples to enrich category descriptions and strive for better classification results.
        """
        
        new_instructions = generate_instructions(meta_prompt)
        new_scores = evaluate_prompts(new_instructions, dataset)
        
        # Update best instructions
        combined = list(zip(best_instructions + new_instructions, best_scores + new_scores))
        combined.sort(key=lambda x: x[1], reverse=True)
        best_instructions = [x[0] for x in combined[:20]]  # keep 20
        best_scores = [x[1] for x in combined[:20]]  # keep 20
        
        print(f"Best instruction: {best_instructions[0]}")
        print(f"Best score: {best_scores[0]}")
        print()
    
    return best_instructions[0], best_scores[0]

# %%
# %%time
# if __name__ == "__main__":
dataset = load_dataset()
best_instruction, best_score = optimize(dataset)
print(f"Final best instruction: {best_instruction}")
print(f"Final best score: {best_score}")
print(f"Stats: {stats}")
# Out:
# Optimizing...
# 111011011100001111111001011010100001111000000000001111111011[0.45, 0.65, 0.55]
# Iteration 1
# Generated prompts: ["You are an AI resume classifier tasked with categorizing resumes into one of the following job roles: {categories}. Analyze the candidate's skills, experience, education, and qualifications to determine the most suitable category for their profile. Draw insights from the provided examples to accurately match resumes to the relevant job category.", "Your role is to develop a resume classification system that can assign incoming resumes to one of the following career fields: {categories}. Carefully review the candidate's background, including their work history, technical skills, accomplishments, and educational training. Utilize the example resumes as a reference to identify key patterns and accurately map new resumes to the corresponding job category.", "As an intelligent resume parser, you must categorize the following resume into one of these occupational categories: {categories}. Examine the candidate's professional summary, core competencies, job responsibilities, and academic credentials. Refer to the given examples to understand the distinguishing characteristics of each category, and make an informed decision about which category best aligns with the candidate's profile."]
# 001011111101000000010101110011011110111110011011000101101110[0.55, 0.7, 0.45]
# Best instruction: Your role is to develop a resume classification system that can assign incoming resumes to one of the following career fields: {categories}. Carefully review the candidate's background, including their work history, technical skills, accomplishments, and educational training. Utilize the example resumes as a reference to identify key patterns and accurately map new resumes to the corresponding job category.
# Best score: 0.7
#
# Iteration 2
# Generated prompts: ["\nAs an AI resume classification assistant, your task is to analyze the given resume and categorize it into one of the following job domains: {categories}. Carefully study the candidate's professional background, including their work experience, core skills, key accomplishments, and educational qualifications. Utilize the provided example resumes to identify relevant patterns and cues that can effectively map the candidate's profile to the most appropriate job category. Aim to capture nuances within each category by considering industry-specific terminology, technical expertise, primary responsibilities, and career trajectories.\n", "\nYou are an intelligent resume screening system designed to classify candidates into one of the following career paths: {categories}. Thoroughly review the resume, focusing on the individual's professional summary, work history, acquired skills, notable achievements, and educational credentials. Refer to the example resumes to gain insights into the distinguishing characteristics associated with each category. Leverage this contextual understanding to accurately match the candidate's qualifications and experience with the relevant job category, ensuring optimal alignment for potential roles and responsibilities.\n", "\nAs a sophisticated resume parser, your objective is to categorize the provided resume into one of the following occupational domains: {categories}. Conduct a comprehensive analysis of the candidate's profile, closely examining their career trajectory, core competencies, key projects or initiatives, educational background, and any industry-specific certifications or training. Consult the example resumes to identify patterns and trends that are indicative of each category's unique requirements and specializations. Employ your contextual understanding to make an informed decision, accurately mapping the candidate's qualifications to the most suitable job category for optimal career prospecting and placement.\n"]
# 001010010001101000001000111001100100001100101001111100111100[0.5, 0.35, 0.45]
# Best instruction: Your role is to develop a resume classification system that can assign incoming resumes to one of the following career fields: {categories}. Carefully review the candidate's background, including their work history, technical skills, accomplishments, and educational training. Utilize the example resumes as a reference to identify key patterns and accurately map new resumes to the corresponding job category.
# Best score: 0.7
#
# Iteration 3
# Generated prompts: ["\nAs an AI-powered resume classifier, your task is to categorize the given resume into one of the following professional domains: {categories}. Conduct a meticulous analysis of the candidate's profile, paying close attention to the following key aspects:\n\n- Professional Experience: Examine the candidate's work history, roles, responsibilities, and industry exposure to identify relevant career trajectories and specializations.\n\n- Core Competencies: Evaluate the technical and transferable skills mentioned, highlighting domain-specific expertise, tools/technologies utilized, and proficiency levels.\n\n- Notable Achievements: Assess significant accomplishments, projects, or initiatives that demonstrate the candidate's capabilities within a particular field or discipline.\n\n- Educational Background: Consider relevant academic qualifications, degrees, certifications, or training programs that align with the job categories provided.\n\nLeverage the example resumes as a reference to understand the distinguishing characteristics, industry-specific terminology, and common patterns associated with each category. Utilize this contextual knowledge to accurately map the candidate's qualifications to the most suitable job domain, ensuring optimal career prospecting and talent acquisition.\n", "\nIn your capacity as an AI resume categorization engine, you are tasked with classifying the provided resume into one of the following occupational fields: {categories}. Undertake a comprehensive evaluation of the candidate's professional profile, considering the following critical elements:\n\n- Career Summary: Analyze the overview or professional statement to gain insights into the candidate's primary focus, industry experience, and career aspirations.\n\n- Job Roles and Responsibilities: Examine the specific roles held, duties performed, and projects undertaken to identify relevant functional areas, industries, and levels of experience.\n\n- Technical Proficiencies: Assess the candidate's proficiency in various tools, technologies, methodologies, and domain-specific skills that align with the job categories provided.\n\n- Accomplishments and Certifications: Scrutinize notable achievements, awards, publications, or certifications that demonstrate exceptional expertise or qualifications within a particular field.\n\n- Educational Qualifications: Consider the candidate's academic background, including degrees, diplomas, or specialized training programs relevant to the job categories.\n\nRefer to the example resumes to comprehend the nuances, industry-specific terminology, and distinguishing characteristics associated with each category. Leverage this contextual understanding to accurately match the candidate's qualifications and experience to the most suitable occupational field, facilitating effective talent acquisition and career development strategies.\n", "\nAs an intelligent resume classification system, your objective is to assign the given resume to one of the following career domains: {categories}. Undertake a rigorous evaluation of the candidate's profile, focusing on the following crucial elements:\n\n- Professional Experience: Scrutinize the candidate's work history, roles, responsibilities, and industry exposure to discern relevant career paths and areas of specialization.\n\n- Core Competencies: Evaluate the technical and soft skills mentioned, highlighting expertise in specific tools, technologies, methodologies, and proficiency levels relevant to the job categories.\n\n- Key Contributions and Initiatives: Assess significant accomplishments, projects, or initiatives that demonstrate the candidate's capabilities, impact, and domain knowledge within a particular field or discipline.\n\n- Educational Qualifications and Training: Consider relevant academic degrees, certifications, professional development programs, or specialized training that align with the requirements of the job categories.\n\n- Career Progressio ...
# 101001110001100100110010001011110100101100111110010111011000[0.5, 0.6, 0.45]
# Best instruction: Your role is to develop a resume classification system that can assign incoming resumes to one of the following career fields: {categories}. Carefully review the candidate's background, including their work history, technical skills, accomplishments, and educational training. Utilize the example resumes as a reference to identify key patterns and accurately map new resumes to the corresponding job category.
# Best score: 0.7
#
# Iteration 4
# Generated prompts: ["\nAs an AI-powered resume classifier, your mission is to meticulously analyze the provided resume and assign it to one of the following professional domains: {categories}. Conduct an in-depth evaluation of the candidate's profile, considering the following critical elements:\n\n- Career Narrative: Carefully examine the professional summary, career objectives, and overall career trajectory to identify the candidate's primary focus, motivations, and industry alignment.\n\n- Roles and Responsibilities: Scrutinize the specific job roles held, key responsibilities undertaken, and projects or initiatives spearheaded to discern the functional areas, industries, and levels of expertise.\n\n- Technical Proficiencies: Assess the candidate's proficiency in various tools, technologies, methodologies, domain-specific skills, and industry-recognized certifications or credentials that align with the provided job categories.\n\n- Notable Achievements and Impact: Evaluate significant accomplishments, awards, publications, or quantifiable results that demonstrate the candidate's exceptional expertise, problem-solving abilities, and contributions within a particular field or discipline.\n\n- Educational Background and Training: Consider the candidate's academic qualifications, degrees, specialized training programs, or continuing education initiatives relevant to the job categories and their respective skill requirements.\n\nLeverage the example resumes as a comprehensive reference, studying the industry-specific terminology, common patterns, and distinguishing characteristics associated with each category. Utilize this contextual knowledge to accurately match the candidate's qualifications, experiences, and aspirations to the most suitable occupational domain, enabling effective talent acquisition, career development strategies, and optimal job matching.\n", "\nIn your role as an intelligent resume categorization engine, you are tasked with classifying the following resume into one of these professional domains: {categories}. Undertake a thorough analysis of the candidate's background, focusing on the following key aspects:\n\n- Professional Experience: Evaluate the candidate's work history, job titles, key responsibilities, and exposure to different industries or sectors to identify relevant career paths and areas of specialization.\n\n- Core Competencies: Assess the technical skills, methodologies, software proficiencies, and domain-specific expertise mentioned, highlighting their relevance and applicability to the given job categories.\n\n- Significant Contributions: Examine notable achievements, successful projects, process improvements, or initiatives spearheaded by the candidate, showcasing their capabilities, impact, and subject matter expertise within a particular field.\n\n- Educational Qualifications: Consider the candidate's academic credentials, including degrees, diplomas, certifications, or specialized training programs that align with the knowledge and skill requirements of the provided job categories.\n\n- Career Progression and Aspirations: Analyze the candidate's overall career trajectory, advancements, and potential growth paths within specific industries or functional areas to gauge their suitability for the categories presented.\n\nRefer to the example resumes to develop a comprehensive understanding of the distinguishing characteristics, industry-specific vocabulary, and common patterns associated with each category. Leverage this contextual knowledge to accurately map the candidate's qualifications, experiences, and career aspirations to the most appropriate professional domain, enabling effective talent acquisition, career development strategies, and optimal job matching.\n", "\nAs a sophisticated AI-driven resume classification system, your objective is to categorize the given resume into one of the following career paths: {categories}. Conduct a comprehensive analysis of the candidate's profile, co ...
# 101001001101111001100110111101001111111101100111001010011000[0.55, 0.7, 0.5]
# Best instruction: Your role is to develop a resume classification system that can assign incoming resumes to one of the following career fields: {categories}. Carefully review the candidate's background, including their work history, technical skills, accomplishments, and educational training. Utilize the example resumes as a reference to identify key patterns and accurately map new resumes to the corresponding job category.
# Best score: 0.7
#
# Iteration 5
# Generated prompts: ["\nAs an AI-powered resume classification engine, your mission is to meticulously analyze the provided resume and assign it to one of the following professional domains: {categories}. Conduct an in-depth evaluation of the candidate's profile, considering these critical elements:\n\n- Career Narrative: Examine the professional summary, career objectives, overall trajectory, and industry focus to discern the primary occupation and specialization.\n\n- Job Titles and Responsibilities: Scrutinize roles held, key duties, projects, initiatives, and accomplishments to identify functional expertise, industry experience, and skill levels.\n\n- Technical Proficiencies: Assess tools, technologies, methodologies, domain-specific skills, certifications, and industry credentials demonstrating relevant abilities.\n\n- Quantifiable Impact: Evaluate metrics, measurable results, awards, and publications highlighting exceptional performance, problem-solving prowess, and subject matter mastery.\n\n- Academic Credentials: Consider degrees, training programs, continued education, and qualifications aligning with each category's knowledge requirements.\n\nLeverage example resumes as a comprehensive guide, studying terminology, patterns, distinguishing traits, and career progression paths typical of each domain. Apply this contextual knowledge to accurately match the candidate's background to the most suitable occupational category, enabling precise talent mapping and career development strategies.\n", "\nServing as a sophisticated AI resume classifier, your objective is to categorize the given resume into one of the following professional fields: {categories}. Conduct an extensive analysis, focusing on these key aspects:\n\n- Career Overview: Examine the summary, background, and overall career trajectory to understand goals, motivations, industries, and areas of focus.\n\n- Professional Experience: Scrutinize roles, responsibilities, projects, accomplishments, and industry exposure to pinpoint relevant career paths and specializations. \n\n- Skill Proficiency: Evaluate technical skills, tools, methodologies, and domain knowledge, highlighting expertise levels aligned with each category.\n\n- Credentials and Training: Assess academic qualifications, certifications, continued education programs, and professional development initiatives pertinent to the job categories.\n\n- Career Progression and Aspirations: Analyze advancements, transitions, and potential growth trajectories within specific fields or functional areas.\n\nRefer to example resumes to comprehend nuances, industry-speak, distinguishing qualifiers, and common career patterns associated with each category. Leverage this contextual intelligence to accurately map the candidate's background to the corresponding professional domain, optimizing job matching and career development opportunities.\n", "\nAs an intelligent resume classification engine, your task is to analyze the provided resume and assign it to one of the following occupational categories: {categories}. Undertake a comprehensive evaluation, focusing on these core elements:\n\n- Career Summary: Examine the professional overview, aspirations, and primary areas of focus to identify potential career paths and specializations.\n\n- Functional Roles: Assess job titles, responsibilities, key contributions, and projects to discern relevant functional expertise, industry knowledge, and proficiency levels.\n\n- Core Competencies: Scrutinize technical skills, tools, methodologies, domain-specific knowledge, and certifications demonstrating applicable abilities.\n\n- Professional Achievements: Evaluate quantifiable results, awards, publications, and initiatives showcasing exceptional performance, problem-solving acumen, and subject matter authority.\n\n- Educational Background: Consider academic degrees, training programs, continued education, and qualifications aligning with each category's knowledge domains.\n\nUtilize e ...
# 011001000111011000111111001011001010000110101011101111110101[0.5, 0.45, 0.75]
# Best instruction:
# As an intelligent resume classification engine, your task is to analyze the provided resume and assign it to one of the following occupational categories: {categories}. Undertake a comprehensive evaluation, focusing on these core elements:
#
# - Career Summary: Examine the professional overview, aspirations, and primary areas of focus to identify potential career paths and specializations.
#
# - Functional Roles: Assess job titles, responsibilities, key contributions, and projects to discern relevant functional expertise, industry knowledge, and proficiency levels.
#
# - Core Competencies: Scrutinize technical skills, tools, methodologies, domain-specific knowledge, and certifications demonstrating applicable abilities.
#
# - Professional Achievements: Evaluate quantifiable results, awards, publications, and initiatives showcasing exceptional performance, problem-solving acumen, and subject matter authority.
#
# - Educational Background: Consider academic degrees, training programs, continued education, and qualifications aligning with each category's knowledge domains.
#
# Utilize example resumes as a contextual guide, studying industry terminology, patterns, distinguishing qualifiers, and typical career trajectories associated with each occupational category. Apply this insight to accurately match the candidate's qualifications and experience to the most relevant job domain, enabling precise talent mapping and career development strategies.
#
# Best score: 0.75
#
# Iteration 6
# Generated prompts: ["\nAs an advanced AI resume classification engine, your role is to meticulously analyze the provided resume and assign it to one of the following professional domains: {categories}. Conduct a comprehensive evaluation, considering these key elements:\n\n- Career Narrative: Carefully examine the professional summary, career highlights, aspirations, and overall trajectory to gain insights into the candidate's primary occupation, industry experience, and areas of specialization.\n\n- Functional Roles and Contributions: Scrutinize job titles, core responsibilities, key projects or initiatives spearheaded, and notable achievements to identify relevant functional expertise, levels of proficiency, and demonstrable impact within specific fields or disciplines.\n\n- Technical Prowess: Evaluate the candidate's proficiency in various tools, technologies, methodologies, programming languages, software applications, and domain-specific skills that align with the provided job categories. Consider industry certifications or credentials as indicators of specialized knowledge.\n\n- Subject Matter Mastery: Assess quantifiable results, publications, awards, or recognitions showcasing exceptional problem-solving abilities, thought leadership, and deep subject matter expertise within a particular domain or industry.\n\n- Educational Background and Professional Development: Consider academic degrees, diplomas, specialized training programs, continuing education initiatives, or professional memberships and affiliations relevant to the job categories and their respective knowledge requirements.\n\nLeverage the example resumes as a comprehensive reference, studying the industry-specific terminology, common patterns, distinguishing characteristics, and typical career progression paths associated with each category. Apply this contextual understanding to accurately match the candidate's qualifications, experiences, and career aspirations to the most suitable occupational domain, enabling precise talent mapping, effective career development strategies, and optimal job matching.\n", "\nServing as an intelligent AI-powered resume classification system, your mission is to meticulously analyze the given resume and categorize it into one of the following professional fields: {categories}. Conduct an in-depth evaluation, focusing on these critical aspects:\n\n- Career Profile: Carefully study the professional summary, career objectives, and overall career trajectory to discern the candidate's primary focus, industry alignment, and long-term aspirations within a specific domain.\n\n- Work Experience and Accomplishments: Examine job roles, key responsibilities, notable projects or initiatives, and quantifiable achievements to identify relevant functional areas, industries, levels of expertise, and demonstrable impact.\n\n- Core Competencies and Proficiencies: Assess the candidate's technical skills, tools, methodologies, programming languages, software applications, and domain-specific knowledge that align with the provided job categories. Consider industry certifications, credentials, or specialized training as indicators of advanced proficiency.\n\n- Thought Leadership and Subject Matter Expertise: Evaluate publications, awards, recognitions, or innovative contributions that showcase the candidate's problem-solving acumen, thought leadership, and deep subject matter expertise within a particular field or discipline.\n\n- Educational Qualifications and Professional Development: Consider academic degrees, diplomas, specialized training programs, continuing education initiatives, or professional memberships and affiliations relevant to the job categories and their respective knowledge requirements.\n\nRefer to the example resumes as a comprehensive guide, studying the industry-specific terminology, common patterns, distinguishing characteristics, and typical career progression paths associated with each category. Leverage this contextual knowle ...
# 101110111111110011100001110001001010101011001101100100000110[0.5, 0.55, 0.55]
# Best instruction:
# As an intelligent resume classification engine, your task is to analyze the provided resume and assign it to one of the following occupational categories: {categories}. Undertake a comprehensive evaluation, focusing on these core elements:
#
# - Career Summary: Examine the professional overview, aspirations, and primary areas of focus to identify potential career paths and specializations.
#
# - Functional Roles: Assess job titles, responsibilities, key contributions, and projects to discern relevant functional expertise, industry knowledge, and proficiency levels.
#
# - Core Competencies: Scrutinize technical skills, tools, methodologies, domain-specific knowledge, and certifications demonstrating applicable abilities.
#
# - Professional Achievements: Evaluate quantifiable results, awards, publications, and initiatives showcasing exceptional performance, problem-solving acumen, and subject matter authority.
#
# - Educational Background: Consider academic degrees, training programs, continued education, and qualifications aligning with each category's knowledge domains.
#
# Utilize example resumes as a contextual guide, studying industry terminology, patterns, distinguishing qualifiers, and typical career trajectories associated with each occupational category. Apply this insight to accurately match the candidate's qualifications and experience to the most relevant job domain, enabling precise talent mapping and career development strategies.
#
# Best score: 0.75
#
# Final best instruction:
# As an intelligent resume classification engine, your task is to analyze the provided resume and assign it to one of the following occupational categories: {categories}. Undertake a comprehensive evaluation, focusing on these core elements:
#
# - Career Summary: Examine the professional overview, aspirations, and primary areas of focus to identify potential career paths and specializations.
#
# - Functional Roles: Assess job titles, responsibilities, key contributions, and projects to discern relevant functional expertise, industry knowledge, and proficiency levels.
#
# - Core Competencies: Scrutinize technical skills, tools, methodologies, domain-specific knowledge, and certifications demonstrating applicable abilities.
#
# - Professional Achievements: Evaluate quantifiable results, awards, publications, and initiatives showcasing exceptional performance, problem-solving acumen, and subject matter authority.
#
# - Educational Background: Consider academic degrees, training programs, continued education, and qualifications aligning with each category's knowledge domains.
#
# Utilize example resumes as a contextual guide, studying industry terminology, patterns, distinguishing qualifiers, and typical career trajectories associated with each occupational category. Apply this insight to accurately match the candidate's qualifications and experience to the most relevant job domain, enabling precise talent mapping and career development strategies.
#
# Final best score: 0.75
# Stats: {'anthropic.claude-3-sonnet-20240229-v1:0': {'in': 30341, 'out': 4438}, 'anthropic.claude-3-haiku-20240307-v1:0': {'in': 839821, 'out': 68476}}
# CPU times: user 3.58 s, sys: 330 ms, total: 3.91 s
# Wall time: 8min 28s
